# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png.](attachment:4b67d91e-22e0-49f1-a27c-d3b1f89f02bb.png)

# %% [markdown]
# El presente trabajo se evidencia las herramientas y ecosistemas de la ciencia de datos

# %% [markdown]
# # *Objetivos*
#
# * Lenguajes utilizados por los científicos de datos
# * Bibliotecas  de la ciencias de datos
# * Herramientas de codigo abierto
# * Ejemplo de expresiones aritméticas utilizando Python

# %% [markdown]
# ![3-intro.png](attachment:0b785bed-b772-49a8-8676-eda962af7488.png)

# %% [markdown]
# Algunos de los lenguajes populares en la ciencia de datos utilizados para el análisis de datos utilizados por los cientificios de datos son los siguiientes:
#
# 1. Python
# 2. R - RStudio
# 3. SQL ( lenguaje de consulta estructurado
# 4. Java - JavaScript
# 5. julia

# %% [markdown]
# ![4-dslanguages.png.png](attachment:4d0c9d65-9454-4cfe-a96d-953542f515c7.png)

# %% [markdown]
# Algunas de las bibliotecas comúnmente utilizadas por los científicos de datos incluyen:
#
# 1. Pandas
# 2. Numpy
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit Learn
# 6. Keras
# 7. TensorFlow
# 8. Pytorch
# 9. ApacheSpark
# 10. Spark:

# %% [markdown]
# ![5-dslibraries.png](attachment:6ca4d9f7-b674-454a-991d-52add9d34c5d.png)

# %% [markdown]
# | *Herramientas de Ciencia de Datos*|
# | ----------------------------------|
# | Visual Studio Code|
# | Jupyter Notebook |
# | Git/ GitHub |

# %% [markdown]
# ![6-dstools.png](attachment:16331416-1b75-49ed-8367-117992c67f3f.png)

# %% [markdown]
# ## Expresiones Aritméticas
#
# * Ejemplos
#
# 1. suma = 5+6
# 2. resta = 7-3
# 3. multiplicacion = 4*5
# 4. division = 20/3
#
# print (suma, resta, multiplicacion, division)

# %% [markdown]
# ![introarithmetic.png](attachment:486b4858-fe99-4200-bb6c-5b82547309da.png)

# %%
#Esta es una expresión aritmética simple para multiplicar y luego sumar enteros
a= 3
b= 4 
c=5 
Expresión = (a*b)+c 
Expresión
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:2e6fc53f-85c5-49f7-90a1-13ccdc13162d.png)

# %%
 # Conversión de minutos a horas 
minutos = 200 
hora= 60 
conversion = minutos/ hora
print (conversion)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png.png](attachment:e451039c-1992-4e34-a642-b1656b119b05.png)

# %% [markdown]
# ![10-objectives.png](attachment:0f89b090-8ff6-4981-a500-2cc3477f0b98.png)

# %% [markdown]
# ## Autor
# Nombre: Yineer Alexis Castillo

# %% [markdown]
# ![11-authordetails.png.png](attachment:3aaa14f4-4a05-4de9-b4cf-d6f37aac43ca.png)

# %% [markdown]
# link: http://localhost:8888/notebooks/DataScienceEcosystem.ipynb
